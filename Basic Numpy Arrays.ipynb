# %% [markdown]
# # Basic Numpy Arrays

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
first = np.array([1, 3, 5, 7])
second = np.array([2,4,6,8])

# %%
first[0], second[0]
# Out:
# (1, 2)

# %%
first[0:2]
# Out:
# array([1, 3])

# %%
second[0], second[1], second[-1]
# Out:
# (2, 4, 8)

# %%
second[[0,1,-1]]
# Out:
# array([2, 4, 8])
